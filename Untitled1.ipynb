# %%
# %%bash
# pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.1.55.tar.gz (23 kB)
# Requirement already satisfied: pandas>=0.24 in c:\users\ggarz\.conda\envs\pythondata\lib\site-packages (from yfinance) (1.0.5)
# Requirement already satisfied: numpy>=1.15 in c:\users\ggarz\.conda\envs\pythondata\lib\site-packages (from yfinance) (1.17.0)
# Requirement already satisfied: requests>=2.20 in c:\users\ggarz\.conda\envs\pythondata\lib\site-packages (from yfinance) (2.24.0)
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.9.tar.gz (8.1 kB)
# Requirement already satisfied: lxml>=4.5.1 in c:\users\ggarz\.conda\envs\pythondata\lib\site-packages (from yfinance) (4.5.2)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\ggarz\.conda\envs\pythondata\lib\site-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\ggarz\.conda\envs\pythondata\lib\site-packages (from pandas>=0.24->yfinance) (2020.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\ggarz\.conda\envs\pythondata\lib\site-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ggarz\.conda\envs\pythondata\lib\site-packages (from requests>=2.20->yfinance) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\ggarz\.conda\envs\pythondata\lib\site-packages (from requests>=2.20->yfinance) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\ggarz\.conda\envs\pythondata\lib\site-packages (from requests>=2.20->yfinance) (2.10)
# Requirement already satisfied: six>=1.5 in c:\users\ggarz\.conda\envs\pythondata\lib\site-packages (from python-dateutil>=2.6.1->pandas>=0.24->yfinance) (1.15.0)
# Building wheels for collected packages: yfinance, multitasking
#   Building wheel for yfinance (setup.py): started
#   Building wheel for yfinance (setup.py): finished with status 'done'
#   Created wheel for yfinance: filename=yfinance-0.1.55-py2.py3-none-any.whl size=22622 sha256=ab6f6bc2231775e0722282d86b69bde13673b40d6902a11290d2bb1266702942
#   Stored in directory: c:\users\ggarz\appdata\local\pip\cache\wheels\68\72\87\a384b8b8139f2489024464d6f5937e6acb2054c57d25519fb9
#   Building wheel for multitasking (setup.py): started
#   Building wheel for multitasking (setup.py): finished with status 'done'
#   Created wheel for multitasking: filename=multitasking-0.0.9-py3-none-any.whl size=8374 sha256=c4820a7ebfaccaa570d4ad58d3eb843d71dd7c59cc4277f8c283bfbb8e052438
#   Stored in directory: c:\users\ggarz\appdata\local\pip\cache\wheels\5e\8a\c4\59c699498647c7c94b14c87a904ca7540646107b3d94b7c320
# Successfully built yfinance multitasking
# Installing collected packages: multitasking, yfinance
# Successfully installed multitasking-0.0.9 yfinance-0.1.55

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
XLK = yf.Ticker("XLK")
print(XLK)
# Out:
# yfinance.Ticker object <XLK>

# %%
XLK.info
# Out:
# {'previousClose': 138.14,
#  'regularMarketOpen': 136.87,
#  'twoHundredDayAverage': 122.360886,
#  'trailingAnnualDividendYield': 0.005936007,
#  'payoutRatio': None,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 137.22,
#  'navPrice': 138.19,
#  'averageDailyVolume10Day': 4647400,
#  'totalAssets': 37484879872,
#  'regularMarketPreviousClose': 138.14,
#  'fiftyDayAverage': 132.13727,
#  'trailingAnnualDividendRate': 0.8200000000000001,
#  'open': 136.87,
#  'toCurrency': None,
#  'averageVolume10days': 4647400,
#  'expireDate': None,
#  'yield': 0.009300000000000001,
#  'algorithm': None,
#  'dividendRate': None,
#  'exDividendDate': None,
#  'beta': None,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 135.54,
#  'priceHint': 2,
#  'currency': 'USD',
#  'regularMarketVolume': 7242922,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': None,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 6407765,
#  'priceToSalesTrailing12Months': None,
#  'dayLow': 135.54,
#  'ask': 137.1,
#  'ytdReturn': None,
#  'askSize': 1100,
#  'volume': 7242922,
#  'fiftyTwoWeekHigh': 139.24,
#  'forwardPE': None,
#  'maxAge': 1,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': None,
#  'fiftyTwoWeekLow': 68.1,
#  'bid': 136.78,
#  'tradeable': False,
#  'dividendYield': None,
#  'bidSize': 900,
#  'dayHigh': 137.22,
#  'exchange': 'PCX',
#  'shortName': 'SPDR Select Sector Fund - Techn',
#  'longName': 'Technology Select Sector SPDR Fund',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EST',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-18000000',
#  'quoteType': 'ETF',
#  'symbol': 'XLK',
#  'messageBoardId': 'finmb_8795639',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': None,
#  'beta3Year': 1.05,
#  'profitMargins': None,
#  'enterpriseToEbitda': None,
#  '52WeekChange': None,
#  'morningStarRiskRating': None,
#  'forwardEps': None,
#  'revenueQuarterlyGrowth': None,
#  'fundInceptionDate': 913766400,
#  'annualReportExpenseRatio': None,
#  'bookValue': None,
#  'fundFamily': 'SPDR State Street Global Advisors',
#  'lastFiscalYearEnd': None,
#  'netIncomeToCommon': None,
#  'trailingEps': None,
#  'lastDividendValue': None,
#  'SandP52WeekChange': None,
#  'priceToBook': None,
#  'nextFiscalYearEnd': None,
#  'mostRecentQuarter': None,
#  'enterpriseValue': None,
#  'threeYearAverageReturn': 0.30660000000000004,
#  'lastSplitDate': None,
#  'lastSplitFactor': None,
#  'legalType': 'Exchange Traded Fund',
#  'lastDividendDate': None,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': None,
#  'pegRatio': None,
#  'lastCapGain': None,
#  'category': 'Technology',
#  'fiveYearAverageReturn': 0.306,
#  'phone': '866-732-8673',
#  'longBusinessSummary': 'The investment seeks investment results that, before expenses, correspond generally to the price and yield performance of publicly traded equity securities of companies in the Technology Select Sector Index.\n In seeking to track the performance of the index, the fund employs a replication strategy, which means that the fund typically invests in substantially all of the securities represented in the index in approximately the same proportions as the index. It generally invests substantially all, but at least 95%, of its total assets in the securities comprising the index. The fund is non-diversified.',
#  'companyOfficers': [],
#  'regularMarketPrice': 136.87,
#  'logo_url': ''}

# %%
XLK.history(period="max")
# Out:
#                   Open        High         Low       Close   Volume  \
# Date
# 1998-12-22   25.105283   25.177912   24.621093   24.826874   300500
# 1998-12-23   25.371591   25.420010   24.911609   25.420010   338300
# 1998-12-24   25.420006   25.420006   25.226330   25.323168   243700
# 1998-12-28   25.710525   25.710525   25.250544   25.395802   309300
# 1998-12-29   25.516845   25.577369   25.177911   25.468426   123800
# ...                ...         ...         ...         ...      ...
# 2021-02-10  137.130005  137.300003  135.220001  136.380005  4732200
# 2021-02-11  137.300003  137.970001  136.770004  137.880005  3781900
# 2021-02-12  137.520004  138.679993  137.139999  138.589996  3376200
# 2021-02-16  139.139999  139.240005  137.779999  138.139999  4858800
# 2021-02-17  136.869995  137.220001  135.539993  136.919998  7242922
#
#             Dividends  Stock Splits
# Date
# 1998-12-22        0.0             0
# 1998-12-23        0.0             0
# 1998-12-24        0.0             0
# 1998-12-28        0.0             0
# 1998-12-29        0.0             0
# ...               ...           ...
# 2021-02-10        0.0             0
# 2021-02-11        0.0             0
# 2021-02-12        0.0             0
# 2021-02-16        0.0             0
# 2021-02-17        0.0             0
#
# [5574 rows x 7 columns]

# %%
ETF = 'XLE XLU XLK XLB XLP XLY XLI XLC XLV XLF XLRE'.split()
ETF
# Out:
# ['XLE', 'XLU', 'XLK', 'XLB', 'XLP', 'XLY', 'XLI', 'XLC', 'XLV', 'XLF', 'XLRE']

# %%
etf_data= yf.download(tickers= ETF, start='2011-02-01', end='2021-02-01')
# Out:
# [*********************100%***********************]  11 of 11 completed

# %%
close = etf_data['Close']

copy_c = close.copy()
copy_c = copy_c.reset_index()
copy_c.describe()
# Out:
#                XLB         XLC          XLE          XLF          XLI  \
# count  2516.000000  659.000000  2516.000000  2516.000000  2516.000000
# mean     48.693283   52.063319    69.099066    20.398200    57.816598
# std       9.195136    6.527248    14.040536     5.817959    15.569812
# min      28.530001   38.970001    23.570000     9.163282    28.400000
# 25%      40.465001   47.845001    63.947500    16.263201    44.875001
# 50%      48.770000   50.279999    69.800003    19.626320    56.150000
# 75%      56.012499   55.835001    77.012501    25.732500    72.212500
# max      77.480003   70.180000   101.290001    31.459999    90.470001
#
#                XLK          XLP         XLRE          XLU          XLV  \
# count  2516.000000  2516.000000  1337.000000  2516.000000  2516.000000
# mean     52.847273    48.317814    33.588970    47.027281    69.078899
# std      25.529981     9.993510     2.872330     9.529242    22.319992
# min      22.520000    28.350000    25.459999    30.200001    29.959999
# 25%      31.840000    40.900002    31.420000    38.070000    49.852501
# 50%      43.240002    50.164999    32.750000    46.830000    71.305000
# 75%      68.785002    55.090000    35.770000    54.034999    86.842497
# max     134.029999    68.150002    41.930000    70.980003   118.500000
#
#                XLY
# count  2516.000000
# mean     81.988418
# std      30.956378
# min      33.840000
# 25%      58.855001
# 50%      78.334999
# 75%     105.712500
# max     170.729996

# %%
copy_c['month_year'] = copy_c['Date'].apply(lambda x: x.strftime('%Y-%m'))
m_close = copy_c[['month_year']]
months = m_close['month_year'].unique()
months_labels = months.tolist()
print(months_labels)
# Out:
# ['2011-02', '2011-03', '2011-04', '2011-05', '2011-06', '2011-07', '2011-08', '2011-09', '2011-10', '2011-11', '2011-12', '2012-01', '2012-02', '2012-03', '2012-04', '2012-05', '2012-06', '2012-07', '2012-08', '2012-09', '2012-10', '2012-11', '2012-12', '2013-01', '2013-02', '2013-03', '2013-04', '2013-05', '2013-06', '2013-07', '2013-08', '2013-09', '2013-10', '2013-11', '2013-12', '2014-01', '2014-02', '2014-03', '2014-04', '2014-05', '2014-06', '2014-07', '2014-08', '2014-09', '2014-10', '2014-11', '2014-12', '2015-01', '2015-02', '2015-03', '2015-04', '2015-05', '2015-06', '2015-07', '2015-08', '2015-09', '2015-10', '2015-11', '2015-12', '2016-01', '2016-02', '2016-03', '2016-04', '2016-05', '2016-06', '2016-07', '2016-08', '2016-09', '2016-10', '2016-11', '2016-12', '2017-01', '2017-02', '2017-03', '2017-04', '2017-05', '2017-06', '2017-07', '2017-08', '2017-09', '2017-10', '2017-11', '2017-12', '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12', '2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2020-01', '2020-02', '2020-03', '2020-04', '2020-05', '2020-06', '2020-07', '2020-08', '2020-09', '2020-10', '2020-11', '2020-12', '2021-01']

# %%
for i, v in enumerate(copy_c.columns):
    print(i,v)
# Out:
# 0 Date
# 1 XLB
# 2 XLC
# 3 XLE
# 4 XLF
# 5 XLI
# 6 XLK
# 7 XLP
# 8 XLRE
# 9 XLU
# 10 XLV
# 11 XLY
# 12 month_year

# %%
plt.figure(figsize=(20,10))

plt.plot(copy_c['Date'], copy_c['XLB'], color='purple', label='Materials')
plt.plot(copy_c['Date'], copy_c['XLC'], color='magenta', label = 'Communication Services')
plt.plot(copy_c['Date'], copy_c['XLE'], color='gold', label='Energy')
plt.plot(copy_c['Date'], copy_c['XLF'], color='green', label='Financials')
plt.plot(copy_c['Date'], copy_c['XLI'], color='skyblue', label='Industrials')
plt.plot(copy_c['Date'], copy_c['XLK'], color='blue', label='Technology')
plt.plot(copy_c['Date'], copy_c['XLP'], color='aqua', label='Consumer Staples')
plt.plot(copy_c['Date'], copy_c['XLRE'], color='red', label='Real Estate')
plt.plot(copy_c['Date'], copy_c['XLU'], color='darkorange', label='Utilities')
plt.plot(copy_c['Date'], copy_c['XLV'], color='deepskyblue', label='Health Care')
plt.plot(copy_c['Date'], copy_c['XLY'], color='yellowgreen', label='Consumer Discretionary')



plt.legend()
plt.xticks(months_labels, rotation=45)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\.conda\envs\pythonData\lib\site-packages\matplotlib\axis.py in convert_units(self, x)
#    1572         try:
# -> 1573             ret = self.converter.convert(x, self.units, self)
#    1574         except Exception as e:
#
# ~\.conda\envs\pythonData\lib\site-packages\matplotlib\dates.py in convert(value, unit, axis)
#    1920         """
# -> 1921         return date2num(value)
#    1922
#
# ~\.conda\envs\pythonData\lib\site-packages\matplotlib\dates.py in date2num(d)
#     436             return d
# --> 437         return _to_ordinalf_np_vectorized(d)
#     438
#
# ~\.conda\envs\pythonData\lib\site-packages\numpy\lib\function_base.py in __call__(self, *args, **kwargs)
#    2090
# -> 2091         return self._vectorize_call(func=func, args=vargs)
#    2092
#
# ~\.conda\envs\pythonData\lib\site-packages\numpy\lib\function_base.py in _vectorize_call(self, func, args)
#    2160         else:
# -> 2161             ufunc, otypes = self._get_ufunc_and_otypes(func=func, args=args)
#    2162
#
# ~\.conda\envs\pythonData\lib\site-packages\numpy\lib\function_base.py in _get_ufunc_and_otypes(self, func, args)
#    2120             inputs = [arg.flat[0] for arg in args]
# -> 2121             outputs = func(*inputs)
#    2122
#
# ~\.conda\envs\pythonData\lib\site-packages\matplotlib\dates.py in _to_ordinalf(dt)
#     221
# --> 222     base = float(dt.toordinal())
#     223
#
# AttributeError: 'numpy.str_' object has no attribute 'toordinal'
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# <ipython-input-12-1544a4473d22> in <module>
#      16
#      17 plt.legend()
# ---> 18 plt.xticks(months_labels, rotation=45)
#      19
#      20 plt.show()
#
# ~\.conda\envs\pythonData\lib\site-packages\matplotlib\pyplot.py in xticks(ticks, labels, **kwargs)
#    1481         labels = ax.get_xticklabels()
#    1482     elif labels is None:
# -> 1483         locs = ax.set_xticks(ticks)
#    1484         labels = ax.get_xticklabels()
#    1485     else:
#
# ~\.conda\envs\pythonData\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     398                 "parameter will become keyword-only %(removal)s.",
#     399                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 400         return func(*args, **kwargs)
#     401
#     402     return wrapper
#
# ~\.conda\envs\pythonData\lib\site-packages\matplotlib\axes\_base.py in set_xticks(self, ticks, minor)
#    3307             Default is ``False``.
#    3308         """
# -> 3309         ret = self.xaxis.set_ticks(ticks, minor=minor)
#    3310         self.stale = True
#    3311         return ret
#
# ~\.conda\envs\pythonData\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     398                 "parameter will become keyword-only %(removal)s.",
#     399                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 400         return func(*args, **kwargs)
#     401
#     402     return wrapper
#
# ~\.conda\envs\pythonData\lib\site-packages\matplotlib\axis.py in set_ticks(self, ticks, minor)
#    1759         """
#    1760         # XXX if the user changes units, the information will be lost here
# -> 1761         ticks = self.convert_units(ticks)
#    1762         if len(ticks) > 1:
#    1763             xleft, xright = self.get_view_interval()
#
# ~\.conda\envs\pythonData\lib\site-packages\matplotlib\axis.py in convert_units(self, x)
#    1574         except Exception as e:
#    1575             raise munits.ConversionError('Failed to convert value(s) to axis '
# -> 1576                                          f'units: {x!r}') from e
#    1577         return ret
#    1578
#
# ConversionError: Failed to convert value(s) to axis units: ['2011-02', '2011-03', '2011-04', '2011-05', '2011-06', '2011-07', '2011-08', '2011-09', '2011-10', '2011-11', '2011-12', '2012-01', '2012-02', '2012-03', '2012-04', '2012-05', '2012-06', '2012-07', '2012-08', '2012-09', '2012-10', '2012-11', '2012-12', '2013-01', '2013-02', '2013-03', '2013-04', '2013-05', '2013-06', '2013-07', '2013-08', '2013-09', '2013-10', '2013-11', '2013-12', '2014-01', '2014-02', '2014-03', '2014-04', '2014-05', '2014-06', '2014-07', '2014-08', '2014-09', '2014-10', '2014-11', '2014-12', '2015-01', '2015-02', '2015-03', '2015-04', '2015-05', '2015-06', '2015-07', '2015-08', '2015-09', '2015-10', '2015-11', '2015-12', '2016-01', '2016-02', '2016-03', '2016-04', '2016-05', '2016-06', '2016-07', '2016-08', '2016-09', '2016-10', '2016-11', '2016-12', '2017-01', '2017-02', '2017-03', '2017-04', '2017-05', '2017-06', '2017-07', '2017-08', '2017-09', '2017-10', '2017-11', '2017-12', '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12', '2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2020-01', '2020-02', '2020-03', '2020-04', '2020-05', '2020-06', '2020-07', '2020-08', '2020-09', '2020-10', '2020-11', '2020-12', '2021-01']
